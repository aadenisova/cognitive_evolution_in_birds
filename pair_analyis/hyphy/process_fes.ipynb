# %%
from Bio import SeqIO
from Bio.Seq import Seq
import pandas as pd
import json
import sys

# %%
PATH_TO_FILES = "/lustre/fs5/jarv_lab/scratch/adenisova/Inno_2025/genome_data/ncbi_dataset/data"

og = "OG0007618"
FEL_FILE = f"{PATH_TO_FILES}/{og}.json"        # или .csv
CODON_ALIGNMENT = f"{PATH_TO_FILES}/alignments/{og}.macse.clean.renamed.fa"
OUTPUT = f"{PATH_TO_FILES}/fel_processed.tsv"

#########################################
# 1. Загрузить FEL-результат
#########################################

f = open(FEL_FILE, "r")
data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['MLE', 'analysis', 'branch attributes', 'data partitions', 'fits', 'input', 'tested', 'timers'])
