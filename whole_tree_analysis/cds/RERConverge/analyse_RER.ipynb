# %%
import pandas as pd

PATH="/lustre/fs5/jarv_lab/scratch/adenisova/Inno_2025/tmp"

cols_of_interest = ["FOODINNO2025_ResEff", "TECHINNO2025_ResEff", "Relative_brain_size", "Wing_length"]

cols_of_interest_dict = dict()

prefix = "TOGA_ALL_selected"
for col in cols_of_interest:
    df = pd.read_csv(
        f"{PATH}/{prefix}_{col}_RERConverge_result.tsv",
        sep = "\t"
    )
    cols_of_interest_dict[col] = df

# %%
cols_of_interest_dict["FOODINNO2025_ResEff"]
# Out:
#            Rho    N         P     p.adj                        gene
# 0    -0.242804  200  0.000532  0.992741  ALDH3A2_rna-XM_015295773.2
# 1    -0.240678  192  0.000772  0.992741     SLC35D3_rna-XM_426171.5
# 2    -0.234460  183  0.001400  0.992741    TMOD2_rna-XM_015291963.2
# 3    -0.220207  197  0.001875  0.992741      NT5DC1_rna-XM_419778.6
# 4    -0.225263  182  0.002233  0.992741      ZNF366_rna-XM_429153.6
# ...        ...  ...       ...       ...                         ...
# 2933 -0.000148  220  0.998254  0.999562    CHADL_rna-XM_025148538.1
# 2934  0.000132  186  0.998578  0.999562   MAP4K5_rna-XM_015276741.2
# 2935  0.000091  201  0.998981  0.999562    OPRK1_rna-NM_001318774.1
# 2936 -0.000050  199  0.999446  0.999562       HSPE1_rna-NM_205067.1
# 2937 -0.000038  206  0.999562  0.999562          rna-XM_015276654.2
#
# [2938 rows x 5 columns]
