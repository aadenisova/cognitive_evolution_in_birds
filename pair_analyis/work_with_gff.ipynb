# %%
import gffpandas.gffpandas as gffpd

df = gffpd.read_gff3(
    '/lustre/fs5/jarv_lab/scratch/adenisova/Inno_2025/genome_data/ncbi_dataset/data/GCF_964188355.1/genomic.gff'
).df

# %%
df["type"].unique()
# Out:
# array(['region', 'gene', 'mRNA', 'exon', 'CDS', 'transcript', 'snoRNA',
#        'lnc_RNA', 'scaRNA', 'pseudogene', 'snRNA', 'cDNA_match', 'tRNA',
#        'rRNA', 'C_gene_segment', 'V_gene_segment'], dtype=object)

# %%
df_RNA = df[df["type"] == "mRNA"]
df_RNA["gene"] = df_RNA["attributes"].apply(lambda x: x.split("gene=")[1].split(";")[0])

df_RNA
# Out:
# /tmp/ipykernel_3456888/136061488.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RNA["gene"] = df_RNA["attributes"].apply(lambda x: x.split("gene=")[1].split(";")[0])
#                  seq_id  source  type  start     end score strand phase  \
# 2           NC_134171.1  Gnomon  mRNA  22538   45521     .      +     .
# 22          NC_134171.1  Gnomon  mRNA  50108   58244     .      -     .
# 31          NC_134171.1  Gnomon  mRNA  50108   58244     .      -     .
# 43          NC_134171.1  Gnomon  mRNA  62247   83762     .      +     .
# 96          NC_134171.1  Gnomon  mRNA  84785  104802     .      +     .
# ...                 ...     ...   ...    ...     ...   ...    ...   ...
# ...

# %%
df_exon = df[df["type"] == "exon"]
df_exon["gene"] = df_exon["attributes"].apply(lambda x: x.split("gene=")[1].split(";")[0])

df_exon
# Out:
# /tmp/ipykernel_3456888/4043754566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exon["gene"] = df_exon["attributes"].apply(lambda x: x.split("gene=")[1].split(";")[0])
#                  seq_id    source  type  start    end score strand phase  \
# 3           NC_134171.1    Gnomon  exon  22538  22786     .      +     .
# 4           NC_134171.1    Gnomon  exon  28758  28940     .      +     .
# 5           NC_134171.1    Gnomon  exon  33712  33889     .      +     .
# 6           NC_134171.1    Gnomon  exon  40099  40272     .      +     .
# 7           NC_134171.1    Gnomon  exon  41801  41951     .      +     .
# ...                 ...       ...   ...    ...    ...   ...    ...   ...
# ...

# %%
df_exon["attributes"].iloc[1]
# Out:
# 'ID=exon-XM_075032257.1-2;Parent=rna-XM_075032257.1;Dbxref=GeneID:142032881,GenBank:XM_075032257.1;gbkey=mRNA;gene=M1AP;product=meiosis 1 associated protein;transcript_id=XM_075032257.1'
